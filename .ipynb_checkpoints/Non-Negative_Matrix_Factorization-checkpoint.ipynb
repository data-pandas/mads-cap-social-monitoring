# %%
#imports
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import warnings
warnings.filterwarnings("ignore")

#read csv
df = pd.read_csv('cleaned_non-vectorized_serve_data.csv')
df = df[~df['text'].isna()]
df
# Out:
#                                                   text   company  \
# 0      lowertown wine amp spirit delivers 4pm free see   grubhub
# 1    maureentiti hi thank contacting 're sorry inco...   grubhub
# 2    “ …in recent month ride-sharing company operat...   grubhub
# 3         rt brandnewmcmann guy yet thatsmycatchphrase   grubhub
# 4    maureentiti hi thank contacting could please d...   grubhub
# ..                                                 ...       ...
# 745  work thing get order n't drink take 10 second ...  doordash
# 746  work thing get order n't drink take 10 second ...  ubereats
# 747  well wont use cuz get hacked easily ppl take r...   grubhub
# 748  well wont use cuz get hacked easily ppl take r...  doordash
# 749  well wont use cuz get hacked easily ppl take r...  ubereats
#
#                          created_at  \
# 0    Mon Jul 18 15:59:52 +0000 2022
# 1    Mon Jul 18 15:46:14 +0000 2022
# 2    Mon Jul 18 15:29:13 +0000 2022
# 3    Mon Jul 18 15:06:53 +0000 2022
# 4    Mon Jul 18 15:39:58 +0000 2022
# ..                              ...
# 745  Mon Aug 01 00:53:25 +0000 2022
# 746  Mon Aug 01 00:53:25 +0000 2022
# 747  Mon Jul 25 00:49:27 +0000 2022
# 748  Mon Jul 25 00:49:27 +0000 2022
# 749  Mon Jul 25 00:49:27 +0000 2022
#
#                                                 tokens
# 0    ['lowertown', 'wine', 'amp', 'spirit', 'delive...
# 1    ['maureentiti', 'hi', 'thank', 'contacting', "...
# 2    ['“', '…in', 'recent', 'month', 'ride-sharing'...
# 3    ['rt', 'brandnewmcmann', 'guy', 'yet', 'thatsm...
# 4    ['maureentiti', 'hi', 'thank', 'contacting', '...
# ..                                                 ...
# 745  ['work', 'thing', 'get', 'order', "n't", 'drin...
# 746  ['work', 'thing', 'get', 'order', "n't", 'drin...
# 747  ['well', 'wont', 'use', 'cuz', 'get', 'hacked'...
# 748  ['well', 'wont', 'use', 'cuz', 'get', 'hacked'...
# 749  ['well', 'wont', 'use', 'cuz', 'get', 'hacked'...
#
# [749 rows x 4 columns]

# %%
# Tuning the parameters for tf-idf
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html
ngram_range=(1,1)
max_df =0.8
min_df =1
max_features=None

# create vectorizer
vectorizer =  TfidfVectorizer()
X = vectorizer.fit_transform(df['text'])
X
# Out:
# <749x2862 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8474 stored elements in Compressed Sparse Row format>

# %%
from sklearn.decomposition import NMF

#arbitrary number of components
n_components = 10

# factor the vectorized matrix into topic-document matrix and term-topic matrix
nmf = NMF(n_components=n_components, random_state=42)
topic_document_matrix = nmf.fit_transform(X)
term_topic_matrix = nmf.components_

# %%
import numpy as np
v = vectorizer.vocabulary_

topic_words=[]
for i in range(n_components):
    topic = term_topic_matrix[i] #extract the topic
    s = sorted(topic, reverse=True)[:10] #get highest scores
    top_words=[]
    for val in s: #loop though highest scores
        max_position = np.where(topic == val)[0][0] #position of term with highest score
        top_word = list(v.keys())[list(v.values()).index(max_position)] #get the top word
        top_words.append(top_word) #append top word
    print("The top 5 words in topic", i , "is", top_words)
    topic_words.append(top_words)
# Out:
# The top 5 words in topic 0 is ['order', 'get', 'food', 'driver', 'use', 'first', '10', 'refund', 'never', 'take']
# The top 5 words in topic 1 is ['amp', 'donut', 'guy', 'area', 'la', 'wwe_mandyrose', 'cream', 'cooky', 'tried', 'available']
# The top 5 words in topic 2 is ['ran', 'allegedly', 'allegedly', 'allegedly', 'allegedly', 'allegedly', 'allegedly', 'allegedly', 'allegedly', 'jersey']
# The top 5 words in topic 3 is ['amazon', 'amid', 'amid', 'amid', 'amid', 'amid', 'amid', 'earnings', 'must', 'marketwatch']
# The top 5 words in topic 4 is ['maxehrich', 'late', 'sleep', 'sleep', 'lol', 'amp', 'rt', 'night', 'love', 'upscalebutta']
# The top 5 words in topic 5 is ['please', 'dm', 'number', 'email', 'account', 'address', 'look', 'phone', 'sorry', 'send']
# The top 5 words in topic 6 is ['yes', 'age', 'age', 'impressive', 'instant', 'etc', 'generalwarphare', 'rt', 'today', 'money']
# The top 5 words in topic 7 is ['prime', 'free', 'fee', 'eligible', 'delivery', 'grubhub', 'one', 'member', 'year', 'favorite']
# The top 5 words in topic 8 is ['ever', 'like', 'lmao', 'coldest', 'coldest', 'coldest', 'coldest', 'coldest', 'line', 'twitter']
# The top 5 words in topic 9 is ['rt', 'ailsaforshaw', 'chang', 'got', 'would', 'done', 'worker', 'man', 'nice', 'fired']

# %%
topic_list=[] #Topic0, Topic1, ...
for i in range(10):
    topic_list.append('Topic'+str(i))

term_list=[] #Term1, Term2, ...
for i in range(1,11):
    term_list.append('Term'+str(i))

# %%
topic_df = pd.DataFrame(topic_words, index=topic_list, columns=term_list)
topic_df
# Out:
#             Term1         Term2      Term3       Term4      Term5  \
# Topic0      order           get       food      driver        use
# Topic1        amp         donut        guy        area         la
# Topic2        ran     allegedly  allegedly   allegedly  allegedly
# Topic3     amazon          amid       amid        amid       amid
# Topic4  maxehrich          late      sleep       sleep        lol
# Topic5     please            dm     number       email    account
# Topic6        yes           age        age  impressive    instant
# Topic7      prime          free        fee    eligible   delivery
# Topic8       ever          like       lmao     coldest    coldest
# Topic9         rt  ailsaforshaw      chang         got      would
#
#                 Term6            Term7      Term8      Term9        Term10
# Topic0          first               10     refund      never          take
# Topic1  wwe_mandyrose            cream      cooky      tried     available
# Topic2      allegedly        allegedly  allegedly  allegedly        jersey
# Topic3           amid             amid   earnings       must   marketwatch
# Topic4            amp               rt      night       love  upscalebutta
# Topic5        address             look      phone      sorry          send
# Topic6            etc  generalwarphare         rt      today         money
# Topic7        grubhub              one     member       year      favorite
# Topic8        coldest          coldest    coldest       line       twitter
# Topic9           done           worker        man       nice         fired

# %%
topic_df.to_csv('topic_terms.csv')

# %% [markdown]
# ### Add topics back into original df and do sampling  for each topic

# %%
topics=[]
for doc in topic_document_matrix:
    topic = np.argmax(doc)#get topic
    topics.append(topic)
    
df['topic']=topics
df
# Out:
#                                                   text   company  \
# 0      lowertown wine amp spirit delivers 4pm free see   grubhub
# 1    maureentiti hi thank contacting 're sorry inco...   grubhub
# 2    “ …in recent month ride-sharing company operat...   grubhub
# 3         rt brandnewmcmann guy yet thatsmycatchphrase   grubhub
# 4    maureentiti hi thank contacting could please d...   grubhub
# ..                                                 ...       ...
# 745  work thing get order n't drink take 10 second ...  doordash
# 746  work thing get order n't drink take 10 second ...  ubereats
# 747  well wont use cuz get hacked easily ppl take r...   grubhub
# 748  well wont use cuz get hacked easily ppl take r...  doordash
# 749  well wont use cuz get hacked easily ppl take r...  ubereats
#
#                          created_at  \
# 0    Mon Jul 18 15:59:52 +0000 2022
# 1    Mon Jul 18 15:46:14 +0000 2022
# 2    Mon Jul 18 15:29:13 +0000 2022
# 3    Mon Jul 18 15:06:53 +0000 2022
# 4    Mon Jul 18 15:39:58 +0000 2022
# ..                              ...
# 745  Mon Aug 01 00:53:25 +0000 2022
# 746  Mon Aug 01 00:53:25 +0000 2022
# 747  Mon Jul 25 00:49:27 +0000 2022
# 748  Mon Jul 25 00:49:27 +0000 2022
# 749  Mon Jul 25 00:49:27 +0000 2022
#
#                                                 tokens  topic
# 0    ['lowertown', 'wine', 'amp', 'spirit', 'delive...      1
# 1    ['maureentiti', 'hi', 'thank', 'contacting', "...      5
# 2    ['“', '…in', 'recent', 'month', 'ride-sharing'...      2
# 3    ['rt', 'brandnewmcmann', 'guy', 'yet', 'thatsm...      9
# 4    ['maureentiti', 'hi', 'thank', 'contacting', '...      5
# ..                                                 ...    ...
# 745  ['work', 'thing', 'get', 'order', "n't", 'drin...      0
# 746  ['work', 'thing', 'get', 'order', "n't", 'drin...      0
# 747  ['well', 'wont', 'use', 'cuz', 'get', 'hacked'...      0
# 748  ['well', 'wont', 'use', 'cuz', 'get', 'hacked'...      0
# 749  ['well', 'wont', 'use', 'cuz', 'get', 'hacked'...      0
#
# [749 rows x 5 columns]

# %%
df.to_csv('tweets_with_topics.csv')
