# %%
#imports
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import warnings
warnings.filterwarnings("ignore")

#read csv
df = pd.read_csv('cleaned_non-vectorized_data.csv')
df = df[~df['Text'].isna()]
df
# Out:
#                                                    Text  \
# 0     come mert ’ today let u take care lunch enjoy ...
# 1     nxt gt lay 20 staff tech 's latest cutback rb_...
# 2          layoff 20 workforce 100 employee sf bay area
# 3     today ’ lunch special smoked pork sausage onio...
# 4     come mert ’ today grab salmon cake two home co...
# ...                                                 ...
# 9277  traik01 cdc people warmed u 2 year ago .... sa...
# 9278  sorry ’ promo code share lately 😭 promos autom...
# 9279                                           poor lad
# 9280  one day able bill order tmobile bill sadly tod...
# 9281                      someone please bless dinner 🥹
#
#                                                  tokens  disgust  joy  anger  \
# 0     ['come', 'mert', '’', 'today', 'let', 'u', 'ta...        0    0      0
# 1     ['nxt', 'gt', 'lay', '20', 'staff', 'tech', "'...        0    0      0
# ...

# %%
from gensim.models import LsiModel
import gensim.corpora as corpora

# Create Dictionary
id2word = corpora.Dictionary(df['Text'].str.split())
# Create Corpus
texts = df['Text'].str.split()
# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]


num_topics = 5

lsi = LsiModel(corpus=corpus, id2word=id2word,num_topics=num_topics)

# %%
import re
for topic in lsi.print_topics():
    i = topic[0]#topic number
    s = topic[1] #string of topics
    l=s.split("+") #list of terms
    terms=[]
    for term in l:
        stripped_term = (re.findall('".+"', term)[0].strip()[1:-1])
        terms.append(stripped_term)
    print("The top words in topic", i, "is", terms)
# Out:
# The top words in topic 0 is ['’', 'order', 'get', 'delivery', 'food', 'amp', 'driver', 'u', "'s", 'like']
# The top words in topic 1 is ['pattern', 'floral', 'gazania', 'abstract', 'flower', 'orange', 'yellow', 'summer', 'taiche', 'petal']
# The top words in topic 2 is ['’', 'order', "'s", 'delivery', 'food', "n't", 'driver', 'u', 'get', '...']
# The top words in topic 3 is ['order', 'get', 'delivery', 'food', 'eats', 'delivered', 'driver', '’', 'sanantoniofood', '👉🏼']
# The top words in topic 4 is ['get', 'delivery', 'food', 'order', 'eats', 'delivered', 'sanantoniofood', '👉🏼', 'safood', 'satxfood']
